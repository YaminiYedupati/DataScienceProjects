# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df_train_survey = pd.read_csv('Surveydata_train_(1).csv')

# %%
df_train_travel = pd.read_csv('Traveldata_train_(1).csv')

# %%
df_train_survey.head()
# Out:
#          ID  Overall_Experience      Seat_comfort Seat_Class  \
# 0  98800001                   0  need improvement  Green Car
# 1  98800002                   0              poor   Ordinary
# 2  98800003                   1  need improvement  Green Car
# 3  98800004                   0        acceptable   Ordinary
# 4  98800005                   1        acceptable   Ordinary
#
#   Arrival_time_convenient          Catering Platform_location  \
# 0               excellent         excellent   very convinient
# 1               excellent              poor  need improvement
# 2        need improvement  need improvement  need improvement
# 3        need improvement               NaN  need improvement
# 4              acceptable        acceptable        manageable
#
#   Onboardwifi_service Onboard_entertainment Online_support Onlinebooking_Ease  \
# 0                good      need improvement     acceptable   need improvement
# ...

# %%
df_train_travel.head()
# Out:
#          ID  Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  98800001  Female  Loyal Customer  52.0              NaN     Business
# 1  98800002    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  98800003  Female  Loyal Customer  43.0  Business travel     Business
# 3  98800004  Female  Loyal Customer  44.0  Business travel     Business
# 4  98800005  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0

# %%
df_train = pd.merge(df_train_travel, df_train_survey, on = 'ID', how = 'inner')

# %%
df_train.head()
# Out:
#          ID  Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  98800001  Female  Loyal Customer  52.0              NaN     Business
# 1  98800002    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  98800003  Female  Loyal Customer  43.0  Business travel     Business
# 3  98800004  Female  Loyal Customer  44.0  Business travel     Business
# 4  98800005  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service Onboard_entertainment  \
# ...

# %%
df_train.to_csv('Train_merged.csv', index = False)

# %%
df_test_survey = pd.read_csv('Surveydata_test.csv')
df_test_travel = pd.read_csv('Traveldata_test.csv')
df_test = pd.merge(df_test_travel, df_test_survey, on = 'ID', how = 'inner')
df_test.to_csv('Test_merged.csv', index = False)

# %%
df_test.head()
# Out:
#          ID  Gender       CustomerType   Age       TypeTravel Travel_Class  \
# 0  99900001  Female                NaN  36.0  Business travel     Business
# 1  99900002  Female  disloyal Customer  21.0  Business travel     Business
# 2  99900003    Male     Loyal Customer  60.0  Business travel     Business
# 3  99900004  Female     Loyal Customer  29.0  Personal Travel          Eco
# 4  99900005    Male  disloyal Customer  18.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              532                     0.0                   0.0
# 1             1425                     9.0                  28.0
# 2             2832                     0.0                   0.0
# 3             1352                     0.0                   0.0
# 4             1610                    17.0                   0.0
#
#      Seat_comfort  ... Onboardwifi_service Onboard_entertainment  \
# ...

# %%
df_test.tail()
# Out:
#              ID  Gender       CustomerType   Age       TypeTravel  \
# 35597  99935598    Male     Loyal Customer   8.0  Personal Travel
# 35598  99935599  Female     Loyal Customer  53.0  Business travel
# 35599  99935600    Male  disloyal Customer  22.0  Business travel
# 35600  99935601  Female     Loyal Customer  67.0  Personal Travel
# 35601  99935602    Male                NaN  20.0  Personal Travel
#
#       Travel_Class  Travel_Distance  DepartureDelay_in_Mins  \
# 35597          Eco             1334                     0.0
# 35598     Business             1772                     0.0
# 35599          Eco             1180                     0.0
# 35600          Eco              420                    23.0
# 35601          Eco             1680                     0.0
#
#        ArrivalDelay_in_Mins      Seat_comfort  ... Onboardwifi_service  \
# 35597                   0.0  need improvement  ...          acceptable
# ...

# %%
df_train = pd.read_csv('Train_merged.csv')

# %%
df_train.shape
# Out:
# (94379, 25)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94379 entries, 0 to 94378
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       94379 non-null  int64
#  1   Gender                   94302 non-null  object
#  2   CustomerType             85428 non-null  object
#  3   Age                      94346 non-null  float64
#  4   TypeTravel               85153 non-null  object
#  5   Travel_Class             94379 non-null  object
#  6   Travel_Distance          94379 non-null  int64
#  7   DepartureDelay_in_Mins   94322 non-null  float64
#  8   ArrivalDelay_in_Mins     94022 non-null  float64
#  9   Overall_Experience       94379 non-null  int64
#  10  Seat_comfort             94318 non-null  object
#  11  Seat_Class               94379 non-null  object
#  12  Arrival_time_convenient  85449 non-null  object
#  13  Catering                 85638 non-null  object
# ...

# %%
df_train.columns
# Out:
# Index(['ID', 'Gender', 'CustomerType', 'Age', 'TypeTravel', 'Travel_Class',
#        'Travel_Distance', 'DepartureDelay_in_Mins', 'ArrivalDelay_in_Mins',
#        'Overall_Experience', 'Seat_comfort', 'Seat_Class',
#        'Arrival_time_convenient', 'Catering', 'Platform_location',
#        'Onboardwifi_service', 'Onboard_entertainment', 'Online_support',
#        'Onlinebooking_Ease', 'Onboard_service', 'Leg_room', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding'],
#       dtype='object')

# %%
#ID column preprocessing
df_train.drop(['ID'], axis = 1, inplace = True)

# %%
df_train.duplicated().sum()
# Out:
# 27

# %%
df_train.drop_duplicates(inplace = True)

# %%
df_train.reset_index(drop = True, inplace = True)

# %%
df_train.shape
# Out:
# (94352, 24)

# %%
df_train.head()
# Out:
#    Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  Female  Loyal Customer  52.0              NaN     Business
# 1    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  Female  Loyal Customer  43.0  Business travel     Business
# 3  Female  Loyal Customer  44.0  Business travel     Business
# 4  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience      Seat_comfort  ... Onboardwifi_service  \
# 0                   0  need improvement  ...                good
# 1                   0              poor  ...                good
# ...

# %%
df_train.tail()
# Out:
#       Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 94347   Male  Loyal Customer  32.0  Business travel     Business
# 94348   Male  Loyal Customer  44.0  Business travel     Business
# 94349   Male             NaN  63.0  Business travel     Business
# 94350   Male  Loyal Customer  16.0  Personal Travel          Eco
# 94351   Male  Loyal Customer  54.0              NaN          Eco
#
#        Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 94347             1357                    83.0                 125.0
# 94348              592                     5.0                  11.0
# 94349             2794                     0.0                   0.0
# 94350             2744                     0.0                   0.0
# 94351             2107                    28.0                  28.0
#
#        Overall_Experience      Seat_comfort  ... Onboardwifi_service  \
# 94347                   0              poor  ...                poor
# ...

# %%
df_train.isnull().sum()
# Out:
# Gender                       77
# CustomerType               8949
# Age                          33
# TypeTravel                 9220
# Travel_Class                  0
# Travel_Distance               0
# DepartureDelay_in_Mins       57
# ArrivalDelay_in_Mins        357
# Overall_Experience            0
# Seat_comfort                 61
# Seat_Class                    0
# Arrival_time_convenient    8928
# Catering                   8740
# Platform_location            30
# Onboardwifi_service          30
# Onboard_entertainment        18
# Online_support               91
# Onlinebooking_Ease           73
# Onboard_service            7599
# Leg_room                     90
# Baggage_handling            142
# Checkin_service              77
# Cleanliness                   6
# Online_boarding               6
# dtype: int64

# %%
df_train.head()
# Out:
#    Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  Female  Loyal Customer  52.0              NaN     Business
# 1    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  Female  Loyal Customer  43.0  Business travel     Business
# 3  Female  Loyal Customer  44.0  Business travel     Business
# 4  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience      Seat_comfort  ... Onboardwifi_service  \
# 0                   0  need improvement  ...                good
# 1                   0              poor  ...                good
# ...

# %%
print(df_train.Gender.value_counts())
print(df_train.CustomerType.value_counts())
print(df_train.Age.median())
print(df_train.TypeTravel.value_counts())
print(df_train.Seat_comfort.value_counts())
print(df_train.Arrival_time_convenient.value_counts())
print(df_train.Catering.value_counts())
print(df_train.Platform_location.value_counts())
print(df_train.Onboardwifi_service.value_counts())
print(df_train.Onboard_entertainment.value_counts())
print(df_train.Online_support.value_counts())
print(df_train.Onlinebooking_Ease.value_counts())
print(df_train.Onboard_service.value_counts())
print(df_train.Leg_room.value_counts())
print(df_train.Baggage_handling.value_counts())
print(df_train.Checkin_service.value_counts())
print(df_train.Cleanliness.value_counts())
print(df_train.Online_boarding.value_counts())
# Out:
# Female    47803
# Male      46472
# Name: Gender, dtype: int64
# Loyal Customer       69798
# disloyal Customer    15605
# Name: CustomerType, dtype: int64
# 40.0
# Business travel    58617
# Personal Travel    26515
# Name: TypeTravel, dtype: int64
# acceptable          21158
# need improvement    20928
# good                20589
# poor                15184
# excellent           12969
# extremely poor       3463
# Name: Seat_comfort, dtype: int64
# good                19557
# excellent           17681
# acceptable          15176
# need improvement    14987
# poor                13691
# extremely poor       4332
# Name: Arrival_time_convenient, dtype: int64
# acceptable          18459
# need improvement    17968
# good                17966
# poor                13857
# excellent           13452
# extremely poor       3910
# Name: Catering, dtype: int64
# manageable           24172
# Convinient           21908
# need improvement     17826
# Inconvinient         16443
# ...

# %% [markdown]
# 1. Gender
#     - replace 77 null values with mode, all existing are Male, Female. (see if you can replace some with male and some with female)
# 2. Customer type - 2 values: loyal customer, disloyal customer
#     - replace 8949 null values with mode.
# 3. Age - replace null values with mean/median
# 4. Type travel has 9220 null values - replace with mode
# 5. Departure delay in mins, arrival delay in mins - impute with avg
# 6. Seat comfort replace with mode
# 7. arrival time convenient with mode
# 8. catering, platform location, onboard wifi, remaining all other cat variables with mode

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94352 entries, 0 to 94351
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   94275 non-null  object
#  1   CustomerType             85403 non-null  object
#  2   Age                      94319 non-null  float64
#  3   TypeTravel               85132 non-null  object
#  4   Travel_Class             94352 non-null  object
#  5   Travel_Distance          94352 non-null  int64
#  6   DepartureDelay_in_Mins   94295 non-null  float64
#  7   ArrivalDelay_in_Mins     93995 non-null  float64
#  8   Overall_Experience       94352 non-null  int64
#  9   Seat_comfort             94291 non-null  object
#  10  Seat_Class               94352 non-null  object
#  11  Arrival_time_convenient  85424 non-null  object
#  12  Catering                 85612 non-null  object
#  13  Platform_location        94322 non-null  object
# ...

# %%
df_train_cat = df_train.select_dtypes(include = 'object')
for cat_column in df_train_cat.columns:
    df_train[cat_column] = df_train[cat_column].fillna(df_train[cat_column].mode()[0])

# %%
df_train.isnull().sum()
# Out:
# Gender                       0
# CustomerType                 0
# Age                         33
# TypeTravel                   0
# Travel_Class                 0
# Travel_Distance              0
# DepartureDelay_in_Mins      57
# ArrivalDelay_in_Mins       357
# Overall_Experience           0
# Seat_comfort                 0
# Seat_Class                   0
# Arrival_time_convenient      0
# Catering                     0
# Platform_location            0
# Onboardwifi_service          0
# Onboard_entertainment        0
# Online_support               0
# Onlinebooking_Ease           0
# Onboard_service              0
# Leg_room                     0
# Baggage_handling             0
# Checkin_service              0
# Cleanliness                  0
# Online_boarding              0
# dtype: int64

# %%
df_train['Age'] = df_train['Age'].fillna(df_train['Age'].median())
df_train['DepartureDelay_in_Mins'] = df_train['DepartureDelay_in_Mins'].fillna(df_train['DepartureDelay_in_Mins'].mean())
df_train['ArrivalDelay_in_Mins'] = df_train['ArrivalDelay_in_Mins'].fillna(df_train['ArrivalDelay_in_Mins'].mean())

# %%
df_train.isnull().sum()
# Out:
# Gender                     0
# CustomerType               0
# Age                        0
# TypeTravel                 0
# Travel_Class               0
# Travel_Distance            0
# DepartureDelay_in_Mins     0
# ArrivalDelay_in_Mins       0
# Overall_Experience         0
# Seat_comfort               0
# Seat_Class                 0
# Arrival_time_convenient    0
# Catering                   0
# Platform_location          0
# Onboardwifi_service        0
# Onboard_entertainment      0
# Online_support             0
# Onlinebooking_Ease         0
# Onboard_service            0
# Leg_room                   0
# Baggage_handling           0
# Checkin_service            0
# Cleanliness                0
# Online_boarding            0
# dtype: int64

# %%
df_train.duplicated().sum()
# Out:
# 1

# %%
df_train.drop_duplicates(inplace=True)

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.shape
# Out:
# (94351, 24)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94351 entries, 0 to 94351
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   94351 non-null  object
#  1   CustomerType             94351 non-null  object
#  2   Age                      94351 non-null  float64
#  3   TypeTravel               94351 non-null  object
#  4   Travel_Class             94351 non-null  object
#  5   Travel_Distance          94351 non-null  int64
#  6   DepartureDelay_in_Mins   94351 non-null  float64
#  7   ArrivalDelay_in_Mins     94351 non-null  float64
#  8   Overall_Experience       94351 non-null  int64
#  9   Seat_comfort             94351 non-null  object
#  10  Seat_Class               94351 non-null  object
#  11  Arrival_time_convenient  94351 non-null  object
#  12  Catering                 94351 non-null  object
#  13  Platform_location        94351 non-null  object
# ...

# %%
df_train.describe(include = 'all').T
# Out:
#                            count unique              top   freq         mean  \
# Gender                     94351      2           Female  47879          NaN
# CustomerType               94351      2   Loyal Customer  78746          NaN
# Age                      94351.0    NaN              NaN    NaN    39.421723
# TypeTravel                 94351      2  Business travel  67837          NaN
# Travel_Class               94351      2              Eco  49315          NaN
# Travel_Distance          94351.0    NaN              NaN    NaN  1978.966402
# DepartureDelay_in_Mins   94351.0    NaN              NaN    NaN    14.647008
# ArrivalDelay_in_Mins     94351.0    NaN              NaN    NaN    15.005734
# Overall_Experience       94351.0    NaN              NaN    NaN     0.546682
# Seat_comfort               94351      6       acceptable  21218          NaN
# Seat_Class                 94351      2        Green Car  47422          NaN
# ...

# %%
sns.boxplot(x = 'Age', data = df_train);

# %%
sns.boxplot(x = 'DepartureDelay_in_Mins', data = df_train);

# %%
sns.boxplot(x = 'ArrivalDelay_in_Mins', data = df_train);

# %%
df_train[df_train['ArrivalDelay_in_Mins'] > 13]['ArrivalDelay_in_Mins'].count()
# Out:
# 23349

# %%
df_train[df_train['DepartureDelay_in_Mins'] > 12]['DepartureDelay_in_Mins'].count()
# Out:
# 23284

# %%
df_train_ot = df_train.copy()

# %%
df_train_ot['DepartureDelay_in_Mins'] = np.where(df_train_ot['DepartureDelay_in_Mins'] > 12, 12, df_train_ot['DepartureDelay_in_Mins'])
df_train_ot['ArrivalDelay_in_Mins'] = np.where(df_train_ot['ArrivalDelay_in_Mins'] > 13, 13, df_train_ot['ArrivalDelay_in_Mins'])

# %%
df_train_ot[df_train_ot['ArrivalDelay_in_Mins'] > 13]['ArrivalDelay_in_Mins'].count()
# Out:
# 0

# %%
df_train_ot[df_train_ot['DepartureDelay_in_Mins'] > 12]['DepartureDelay_in_Mins'].count()
# Out:
# 0

# %%
sns.boxplot(x = 'ArrivalDelay_in_Mins', data = df_train_ot);

# %%
sns.boxplot(x = 'DepartureDelay_in_Mins', data = df_train_ot);

# %%
df_train['Overall_Experience'].value_counts()
# Out:
# 1    51580
# 0    42771
# Name: Overall_Experience, dtype: int64

# %%
#converting all uint columns in dataset to categorical
catcolumns = ['Gender', 'CustomerType', 'TypeTravel', 'Travel_Class', 'Seat_Class']
df_train_encoded = pd.get_dummies(data = df_train, columns = catcolumns, drop_first = True)

# %%
df_train_encoded.head()
# Out:
#     Age  Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0  52.0              272                     0.0                   5.0
# 1  48.0             2200                     9.0                   0.0
# 2  43.0             1061                    77.0                 119.0
# 3  44.0              780                    13.0                  18.0
# 4  50.0             1981                     0.0                   0.0
#
#    Overall_Experience      Seat_comfort Arrival_time_convenient  \
# 0                   0  need improvement               excellent
# 1                   0              poor               excellent
# 2                   1  need improvement        need improvement
# 3                   0        acceptable        need improvement
# 4                   1        acceptable              acceptable
#
#            Catering Platform_location Onboardwifi_service  ...  \
# 0         excellent   very convinient                good  ...
# ...

# %%
print(df_train_encoded.Seat_comfort.value_counts())
print(df_train_encoded.Arrival_time_convenient.value_counts())
print(df_train_encoded.Catering.value_counts())
print(df_train_encoded.Platform_location.value_counts())
print(df_train_encoded.Onboardwifi_service.value_counts())
print(df_train_encoded.Onboard_entertainment.value_counts())
print(df_train_encoded.Online_support.value_counts())
print(df_train_encoded.Onlinebooking_Ease.value_counts())
print(df_train_encoded.Onboard_service.value_counts())
print(df_train_encoded.Leg_room.value_counts())
print(df_train_encoded.Baggage_handling.value_counts())
print(df_train_encoded.Checkin_service.value_counts())
print(df_train_encoded.Cleanliness.value_counts())
print(df_train_encoded.Online_boarding.value_counts())
# Out:
# acceptable          21218
# need improvement    20928
# good                20589
# poor                15184
# excellent           12969
# extremely poor       3463
# Name: Seat_comfort, dtype: int64
# good                28485
# excellent           17681
# acceptable          15175
# need improvement    14987
# poor                13691
# extremely poor       4332
# Name: Arrival_time_convenient, dtype: int64
# acceptable          27198
# need improvement    17968
# good                17966
# poor                13857
# excellent           13452
# extremely poor       3910
# Name: Catering, dtype: int64
# manageable           24201
# Convinient           21908
# need improvement     17826
# Inconvinient         16443
# very convinient      13971
# very inconvinient        2
# Name: Platform_location, dtype: int64
# good                22856
# excellent           20962
# acceptable          20115
# need improvement    19591
# poor                10736
# extremely poor         91
# ...

# %%
#replace categories with ordinal labels.
ordinal_dict = {'extremely poor':1,'poor':2,'need improvement':3,'acceptable':4,'good':5,'excellent':6}
for i in ordinal_dict:
    df_train_encoded.Seat_comfort = df_train_encoded.Seat_comfort.replace(i, ordinal_dict[i])
    df_train_encoded.Arrival_time_convenient = df_train_encoded.Arrival_time_convenient.replace(i, ordinal_dict[i])
    df_train_encoded.Catering = df_train_encoded.Catering.replace(i, ordinal_dict[i])
    df_train_encoded.Onboardwifi_service = df_train_encoded.Onboardwifi_service.replace(i, ordinal_dict[i])
    df_train_encoded.Onboard_entertainment = df_train_encoded.Onboard_entertainment.replace(i, ordinal_dict[i])
    df_train_encoded.Online_support = df_train_encoded.Online_support.replace(i, ordinal_dict[i])
    df_train_encoded.Onlinebooking_Ease = df_train_encoded.Onlinebooking_Ease.replace(i, ordinal_dict[i])
    df_train_encoded.Onboard_service = df_train_encoded.Onboard_service.replace(i, ordinal_dict[i])
    df_train_encoded.Leg_room = df_train_encoded.Leg_room.replace(i, ordinal_dict[i])
    df_train_encoded.Baggage_handling = df_train_encoded.Baggage_handling.replace(i, ordinal_dict[i])
    df_train_encoded.Checkin_service = df_train_encoded.Checkin_service.replace(i, ordinal_dict[i])
    df_train_encoded.Cleanliness = df_train_encoded.Cleanliness.replace(i, ordinal_dict[i])
    df_train_encoded.Online_boarding = df_train_encoded.Online_boarding.replace(i, ordinal_dict[i])

platform_location_dict = {'very inconvinient': 1,'Inconvinient': 2,'need improvement': 3,'manageable': 4,'Convinient': 5,'very convinient': 6}

for i in platform_location_dict:
    df_train_encoded.Platform_location = df_train_encoded.Platform_location.replace(i, platform_location_dict[i])

# %%
print(df_train_encoded.Seat_comfort.value_counts())
print(df_train_encoded.Arrival_time_convenient.value_counts())
print(df_train_encoded.Catering.value_counts())
print(df_train_encoded.Platform_location.value_counts())
print(df_train_encoded.Onboardwifi_service.value_counts())
print(df_train_encoded.Onboard_entertainment.value_counts())
print(df_train_encoded.Online_support.value_counts())
print(df_train_encoded.Onlinebooking_Ease.value_counts())
print(df_train_encoded.Onboard_service.value_counts())
print(df_train_encoded.Leg_room.value_counts())
print(df_train_encoded.Baggage_handling.value_counts())
print(df_train_encoded.Checkin_service.value_counts())
print(df_train_encoded.Cleanliness.value_counts())
print(df_train_encoded.Online_boarding.value_counts())
# Out:
# 4    21218
# 3    20928
# 5    20589
# 2    15184
# 6    12969
# 1     3463
# Name: Seat_comfort, dtype: int64
# 5    28485
# 6    17681
# 4    15175
# 3    14987
# 2    13691
# 1     4332
# Name: Arrival_time_convenient, dtype: int64
# 4    27198
# 3    17968
# 5    17966
# 2    13857
# 6    13452
# 1     3910
# Name: Catering, dtype: int64
# 4    24201
# 5    21908
# 3    17826
# 2    16443
# 6    13971
# 1        2
# Name: Platform_location, dtype: int64
# 5    22856
# 6    20962
# 4    20115
# 3    19591
# 2    10736
# 1       91
# Name: Onboardwifi_service, dtype: int64
# 5    30460
# 6    21639
# 4    17550
# 3    13917
# 2     8641
# 1     2144
# Name: Onboard_entertainment, dtype: int64
# 5    30095
# 6    25888
# 4    15699
# 3    12504
# 2    10164
# 1        1
# Name: Online_support, dtype: int64
# 5    28966
# 6    24741
# 4    16387
# 3    14476
# 2     9765
# 1       16
# Name: Onlinebooking_Ease, dtype: int64
# 5    34853
# 6    21268
# 4    18061
# 3    11389
# ...

# %%
#Changing all datatypes to category since all are categorical in this case.

for i in df_train_encoded.select_dtypes(include = 'object'):
    df_train_encoded[i] = pd.Categorical(df_train_encoded[i])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94351 entries, 0 to 94351
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   94351 non-null  object
#  1   CustomerType             94351 non-null  object
#  2   Age                      94351 non-null  float64
#  3   TypeTravel               94351 non-null  object
#  4   Travel_Class             94351 non-null  object
#  5   Travel_Distance          94351 non-null  int64
#  6   DepartureDelay_in_Mins   94351 non-null  float64
#  7   ArrivalDelay_in_Mins     94351 non-null  float64
#  8   Overall_Experience       94351 non-null  int64
#  9   Seat_comfort             94351 non-null  object
#  10  Seat_Class               94351 non-null  object
#  11  Arrival_time_convenient  94351 non-null  object
#  12  Catering                 94351 non-null  object
#  13  Platform_location        94351 non-null  object
# ...

# %%
df_train_encoded.head()
# Out:
#     Age  Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0  52.0              272                     0.0                   5.0
# 1  48.0             2200                     9.0                   0.0
# 2  43.0             1061                    77.0                 119.0
# 3  44.0              780                    13.0                  18.0
# 4  50.0             1981                     0.0                   0.0
#
#    Overall_Experience  Seat_comfort  Arrival_time_convenient  Catering  \
# 0                   0             3                        6         6
# 1                   0             2                        6         2
# 2                   1             3                        3         3
# 3                   0             4                        3         4
# 4                   1             4                        4         4
#
#    Platform_location  Onboardwifi_service  ...  Leg_room  Baggage_handling  \
# ...

# %%
df_train_encoded.tail()
# Out:
#         Age  Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 94347  32.0             1357                    83.0                 125.0
# 94348  44.0              592                     5.0                  11.0
# 94349  63.0             2794                     0.0                   0.0
# 94350  16.0             2744                     0.0                   0.0
# 94351  54.0             2107                    28.0                  28.0
#
#        Overall_Experience  Seat_comfort  Arrival_time_convenient  Catering  \
# 94347                   0             2                        5         5
# 94348                   1             5                        5         5
# 94349                   1             3                        3         3
# 94350                   0             3                        5         3
# 94351                   0             4                        2         4
#
#        Platform_location  Onboardwifi_service  ...  Leg_room  \
# ...

# %%
X_train = df_train_encoded.drop('Overall_Experience', axis = 1)

# %%
y_train = df_train_encoded['Overall_Experience']

# %%
X_train.head()
# Out:
#     Age  Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0  52.0              272                     0.0                   5.0
# 1  48.0             2200                     9.0                   0.0
# 2  43.0             1061                    77.0                 119.0
# 3  44.0              780                    13.0                  18.0
# 4  50.0             1981                     0.0                   0.0
#
#    Seat_comfort  Arrival_time_convenient  Catering  Platform_location  \
# 0             3                        6         6                  6
# 1             2                        6         2                  3
# 2             3                        3         3                  3
# 3             4                        3         4                  3
# 4             4                        4         4                  4
#
#    Onboardwifi_service  Onboard_entertainment  ...  Leg_room  \
# ...

# %%
y_train.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Overall_Experience, dtype: int64

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.externals import joblib
help(joblib.parallel)
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
#rfc = RandomForestClassifier(n_estimators=10, max_depth= 20, max_features= 10, min_samples_split = 2, min_samples_leaf = 1, random_state = 100,n_jobs=-1)
rf = RandomForestClassifier(n_estimators=1000, max_depth= 10, max_features= 10, random_state = 100,n_jobs=-1, verbose=100)

ADB_model=AdaBoostClassifier(n_estimators=3000,random_state=1,base_estimator=rf,learning_rate=0.5)
ADB_model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8400\2238078469.py in <module>
# ----> 1 from sklearn.externals import joblib
#       2 help(joblib.parallel)
#       3 from sklearn.ensemble import AdaBoostClassifier
#       4 from sklearn.ensemble import RandomForestClassifier
#       5 #rfc = RandomForestClassifier(n_estimators=10, max_depth= 20, max_features= 10, min_samples_split = 2, min_samples_leaf = 1, random_state = 100,n_jobs=-1)
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\yamin\anaconda3\lib\site-packages\sklearn\externals\__init__.py)

# %%
gbc_model.score(X_train, y_train)
#ADB_model.score(X_train, y_train)

# %%
df_test = pd.read_csv('Test_merged.csv')

#ID column preprocessing
df_test.drop(['ID'], axis = 1, inplace = True)

df_test_cat = df_test.select_dtypes(include = 'object')
for cat_column in df_test_cat.columns:
    df_test[cat_column] = df_test[cat_column].fillna(df_test[cat_column].mode()[0])

df_test['Age'] = df_test['Age'].fillna(df_test['Age'].median())
df_test['DepartureDelay_in_Mins'] = df_test['DepartureDelay_in_Mins'].fillna(df_test['DepartureDelay_in_Mins'].mean())
df_test['ArrivalDelay_in_Mins'] = df_test['ArrivalDelay_in_Mins'].fillna(df_test['ArrivalDelay_in_Mins'].mean())

#converting all uint columns in dataset to categorical
catcolumns = ['Gender', 'CustomerType', 'TypeTravel', 'Travel_Class', 'Seat_Class']
df_test_encoded = pd.get_dummies(data = df_test, columns = catcolumns, drop_first = True)

#replace categories with ordinal labels.
ordinal_dict = {'extremely poor':1,'poor':2,'need improvement':3,'acceptable':4,'good':5,'excellent':6}
for i in ordinal_dict:
    df_test_encoded.Seat_comfort = df_test_encoded.Seat_comfort.replace(i, ordinal_dict[i])
    df_test_encoded.Arrival_time_convenient = df_test_encoded.Arrival_time_convenient.replace(i, ordinal_dict[i])
    df_test_encoded.Catering = df_test_encoded.Catering.replace(i, ordinal_dict[i])
    df_test_encoded.Onboardwifi_service = df_test_encoded.Onboardwifi_service.replace(i, ordinal_dict[i])
    df_test_encoded.Onboard_entertainment = df_test_encoded.Onboard_entertainment.replace(i, ordinal_dict[i])
    df_test_encoded.Online_support = df_test_encoded.Online_support.replace(i, ordinal_dict[i])
    df_test_encoded.Onlinebooking_Ease = df_test_encoded.Onlinebooking_Ease.replace(i, ordinal_dict[i])
    df_test_encoded.Onboard_service = df_test_encoded.Onboard_service.replace(i, ordinal_dict[i])
    df_test_encoded.Leg_room = df_test_encoded.Leg_room.replace(i, ordinal_dict[i])
    df_test_encoded.Baggage_handling = df_test_encoded.Baggage_handling.replace(i, ordinal_dict[i])
    df_test_encoded.Checkin_service = df_test_encoded.Checkin_service.replace(i, ordinal_dict[i])
    df_test_encoded.Cleanliness = df_test_encoded.Cleanliness.replace(i, ordinal_dict[i])
    df_test_encoded.Online_boarding = df_test_encoded.Online_boarding.replace(i, ordinal_dict[i])

platform_location_dict = {'very inconvinient': 1,'Inconvinient': 2,'need improvement': 3,'manageable': 4,'Convinient': 5,'very convinient': 6}

for i in platform_location_dict:
    df_test_encoded.Platform_location = df_test_encoded.Platform_location.replace(i, platform_location_dict[i])

#Changing all datatypes to category since all are categorical in this case.

for i in df_test_encoded.select_dtypes(include = 'object'):
    df_test_encoded[i] = pd.Categorical(df_test_encoded[i])

# %%
df_test_encoded.head()

# %%
df_test_encoded.tail()

# %%
X_test = df_test_encoded

# %%
y_test_predicted = ADB_model.predict(X_test)
#y_test_predicted = grid_search_rfc_best2.predict(X_test)

# %%
y_test_predicted

# %%
df_test1 = pd.read_csv('Test_merged.csv') 
data = { 'ID':list(df_test1['ID']), 'Overall_Experience':list(y_test_predicted) }

df2 = pd.DataFrame(data)

df2.to_csv('Submission.csv',index=False)
